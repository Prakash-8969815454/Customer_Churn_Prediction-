# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Telco-Customer-Churn.csv")

# %%
data.head(10)
# Out:
#    SeniorCitizen  tenure  ...  TotalCharges_999.8  TotalCharges_999.9
# 0              0       1  ...               False               False
# 1              0      34  ...               False               False
# 2              0       2  ...               False               False
# 3              0      45  ...               False               False
# 4              0       2  ...               False               False
# 5              0       8  ...               False               False
# 6              0      22  ...               False               False
# 7              0      10  ...               False               False
# 8              0      28  ...               False               False
# 9              0      62  ...               False               False
#
# [10 rows x 13602 columns]

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Columns: 13602 entries, SeniorCitizen to TotalCharges_999.9
# dtypes: bool(13598), float64(1), int64(3)
# memory usage: 91.5 MB
#        SeniorCitizen       tenure  MonthlyCharges        Churn
# count    7043.000000  7043.000000     7043.000000  7043.000000
# mean        0.162147    32.371149       64.761692     0.265370
# std         0.368612    24.559481       30.090047     0.441561
# min         0.000000     0.000000       18.250000     0.000000
# 25%         0.000000     9.000000       35.500000     0.000000
# 50%         0.000000    29.000000       70.350000     0.000000
# 75%         0.000000    55.000000       89.850000     1.000000
# max         1.000000    72.000000      118.750000     1.000000

# %%
data.isnull().sum()
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
sns.countplot(x = 'Churn',data = data)
plt.title("Churn Distribution")
plt.show()

# %%
data[['MonthlyCharges','tenure']].hist(figsize=(10,5))
plt.show()

# %%
sns.boxplot(x = 'Churn',y = 'tenure',data = data)
plt.show()
sns.boxplot(x = 'Churn',y = 'MonthlyCharges',data = data)
plt.show()

# %%
sns.countplot(x = 'Contract',hue='Churn',data = data)
plt.show()

# %%
data.dropna(how= 'any',axis = 0,inplace= True)
data['Churn'] = data['Churn'].map({'Yes':1,'No':0})

# %%
data = pd.get_dummies(data,drop_first= True)
x = data.drop('Churn',axis=1)
y = data['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state= 42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(16,activation='relu',input_shape=[x_train.shape[1]]),
                             tf.keras.layers.Dense(8,activation='relu'),
                             tf.keras.layers.Dense(1,activation='sigmoid')])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %%
train_model = model.fit(x_train,y_train,epochs= 50,batch_size=16,validation_split=  0.2)
# Out:
# Epoch 1/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9988 - loss: 0.0054 - val_accuracy: 0.6273 - val_loss: 0.6402
# Epoch 2/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9979 - loss: 0.0076 - val_accuracy: 0.5821 - val_loss: 0.6872
# Epoch 3/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9997 - loss: 0.0044 - val_accuracy: 0.5430 - val_loss: 0.7281
# Epoch 4/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.5253 - val_loss: 0.7685
# Epoch 5/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9998 - loss: 0.0038 - val_accuracy: 0.4969 - val_loss: 0.8151
# Epoch 6/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.5288 - val_loss: 0.7721
# Epoch 7/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9998 - loss: 0.0021 - val_accuracy: 0.5155 - val_loss: 0.8041
# Epoch 8/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9997 - loss: 0.0019 - val_accuracy: 0.4827 - val_loss: 0.8674
# Epoch 9/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.4827 - val_loss: 0.8789
# Epoch 10/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.4676 - val_loss: 0.9229
# Epoch 11/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.4472 - val_loss: 0.9884
# Epoch 12/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.4712 - val_loss: 0.9523
# Epoch 13/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 6.5425e-04 - val_accuracy: 0.4508 - val_loss: 1.0090
# Epoch 14/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.0580e-04 - val_accuracy: 0.4303 - val_loss: 1.0578
# Epoch 15/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 4.3582e-04 - val_accuracy: 0.4224 - val_loss: 1.1049
# Epoch 16/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 4.5906e-04 - val_accuracy: 0.4135 - val_loss: 1.1377
# Epoch 17/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9997 - loss: 0.0010 - val_accuracy: 0.4046 - val_loss: 1.1805
# Epoch 18/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9999 - loss: 4.5090e-04 - val_accuracy: 0.4002 - val_loss: 1.2142
# Epoch 19/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 7.4576e-04 - val_accuracy: 0.3895 - val_loss: 1.2449
# Epoch 20/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.3878 - val_loss: 1.2810
# Epoch 21/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9998 - loss: 5.8713e-04 - val_accuracy: 0.3753 - val_loss: 1.3279
# Epoch 22/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 2.7624e-04 - val_accuracy: 0.3780 - val_loss: 1.3502
# Epoch 23/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9999 - loss: 4.0485e-04 - val_accuracy: 0.3744 - val_loss: 1.3774
# Epoch 24/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 3.3052e-04 - val_accuracy: 0.3744 - val_loss: 1.4154
# Epoch 25/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9999 - loss: 4.9871e-04 - val_accuracy: 0.3700 - val_loss: 1.4667
# Epoch 26/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.3649e-04 - val_accuracy: 0.3753 - val_loss: 1.4904
# Epoch 27/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9998 - loss: 4.4032e-04 - val_accuracy: 0.3727 - val_loss: 1.5396
# Epoch 28/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 2.3836e-04 - val_accuracy: 0.3665 - val_loss: 1.5925
# Epoch 29/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9998 - loss: 4.3959e-04 - val_accuracy: 0.3647 - val_loss: 1.6519
# Epoch 30/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9999 - loss: 2.6586e-04 - val_accuracy: 0.3594 - val_loss: 1.7178
# Epoch 31/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9998 - loss: 6.0591e-04 - val_accuracy: 0.3744 - val_loss: 1.6851
# Epoch 32/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9999 - loss: 2.7113e-04 - val_accuracy: 0.3647 - val_loss: 1.6764
# Epoch 33/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 1.6619e-04 - val_accuracy: 0.3647 - val_loss: 1.7090
# Epoch 34/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 1.5149e-04 - val_accuracy: 0.3629 - val_loss: 1.7418
# Epoch 35/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9997 - loss: 4.7364e-04 - val_accuracy: 0.3585 - val_loss: 1.7833
# Epoch 36/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9996 - loss: 5.0386e-04 - val_accuracy: 0.3540 - val_loss: 1.8356
# Epoch 37/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9997 - loss: 3.4958e-04 - val_accuracy: 0.3523 - val_loss: 1.8754
# Epoch 38/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9994 - loss: 6.5001e-04 - val_accuracy: 0.3540 - val_loss: 1.8928
# Epoch 39/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9999 - loss: 1.2471e-04 - val_accuracy: 0.3505 - val_loss: 1.9506
# Epoch 40/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 6.2506e-05 - val_accuracy: 0.3496 - val_loss: 2.0119
# Epoch 41/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 1.9009e-04 - val_accuracy: 0.3478 - val_loss: 2.0868
# Epoch 42/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 1.0000 - loss: 1.6112e-04 - val_accuracy: 0.3434 - val_loss: 2.1586
# Epoch 43/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 6.6259e-05 - val_accuracy: 0.3372 - val_loss: 2.2431
# Epoch 44/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 7.0578e-05 - val_accuracy: 0.3319 - val_loss: 2.3410
# Epoch 45/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 5.8758e-05 - val_accuracy: 0.3283 - val_loss: 2.4226
# Epoch 46/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 3.4923e-05 - val_accuracy: 0.3239 - val_loss: 2.5001
# Epoch 47/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 3.9962e-05 - val_accuracy: 0.3221 - val_loss: 2.5854
# Epoch 48/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 1.0000 - loss: 1.8516e-05 - val_accuracy: 0.3203 - val_loss: 2.6705
# Epoch 49/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 2.3850e-05 - val_accuracy: 0.3177 - val_loss: 2.7591
# Epoch 50/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 1.2701e-05 - val_accuracy: 0.3567 - val_loss: 2.6376

# %%
y_pred = (model.predict(x_test) > 0.5).astype(int)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[469 567]
#  [ 39 334]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.45      0.61      1036
#            1       0.37      0.90      0.52       373
#
#     accuracy                           0.57      1409
#    macro avg       0.65      0.67      0.57      1409
# weighted avg       0.78      0.57      0.59      1409
